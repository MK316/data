# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/data/blob/main/Freq_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("punkt")

import pandas as pd
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
print('Copy and paste your text into the box below and hit ENTER key.')
copytext = input()
text = copytext
# Out:
# Copy and paste your text into the box below and hit ENTER key.
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
wc = WordCloud().generate(text) 
plt.imshow(wc)

# %%
words = word_tokenize(text)
print('Total words: ', len(words))
print(words)
# Out:
# Total words:  10234
# ...

# %%
# Word list with longer than 3 letter. Without punctuation:
wordlist = []
for w in words:
  if len(w) > 3:
    wordlist.append(w)
print('Total words: ', len(wordlist))
print(wordlist)
# Out:
# Total words:  5006
# ...

# %%
fd = nltk.FreqDist(wordlist).most_common(20)
df = pd.DataFrame(fd,columns = ['Word','Freq']) 
df
# Out:
#             Word  Freq
# 0           with    79
# 1        voicing    62
# 2           that    51
# 3     production    47
# 4         voiced    41
# 5     perception    40
# 6         tokens    39
# 7       plosives    37
# 8       CrossRef    37
# 9        speaker    36
# 10          were    36
# 11    prevoicing    35
# 12        effect    34
# 13         vowel    33
# 14          male    32
# 15         voice    31
# 16       Russian    30
# 17         place    30
# 18  articulation    30
# 19          also    30

# %%
fd = nltk.FreqDist(words).most_common(5006)
df = pd.DataFrame(fd,columns = ['Word','Freq']) 
df.tail(20)
# Out:
#                Word  Freq
# 2231    Variability     1
# 2232     Processing     1
# 2233      Mullennix     1
# 2234           J.W.     1
# 2235        145–165     1
# 2236  Pierrehumbert     1
# 2237           J.B.     1
# 2238       Exemplar     1
# 2239       dynamics     1
# 2240       lenition     1
# 2241      Frequency     1
# 2242      Emergence     1
# 2243     Linguistic     1
# 2244      Structure     1
# 2245          Bybee     1
# 2246         Hooper     1
# 2247           John     1
# 2248      Benjamins     1
# 2249      Amsterdam     1
# 2250           2001     1
